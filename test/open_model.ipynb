# %%
import mlflow

# This also works for Keras models
model = mlflow.pyfunc.load_model("file:///D:/Mestrado/redes_neurais/video_tennis_analysis/video_tennis_analysis/mlruns/316340092913734607/566ba901dd404e6fb5a7a429ae95fe51/artifacts/model")
# # or
# model = mlflow.pyfunc.load_model("models:/<model_name>/<version>")

# %%
print(model)
# Out:
# mlflow.pyfunc.loaded_model:
#   artifact_path: model
#   flavor: mlflow.keras
#   run_id: 566ba901dd404e6fb5a7a429ae95fe51
